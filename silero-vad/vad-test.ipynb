# %%
import torch
model, utils = torch.hub.load(repo_or_dir='snakers4/silero-vad', model='silero_vad')
# Out:
# Using cache found in /home/cjbayron/.cache/torch/hub/snakers4_silero-vad_master
# ################################################################################
# ### WARNING, path does not exist: KALDI_ROOT=/mnt/matylda5/iveselyk/Tools/kaldi-trunk
# ###          (please add 'export KALDI_ROOT=<your_path>' in your $HOME/.profile)
# ###          (or run as: KALDI_ROOT=<your_path> python <your_script>.py)
# ################################################################################

# %%
(get_speech_ts,
 save_audio,
 read_audio,
 state_generator,
 single_audio_stream,
 collect_chunks) = utils

# %%
help(single_audio_stream)
# Out:
# Help on function single_audio_stream in module utils_vad:
#
# single_audio_stream(model, audio:str, onnx:bool=False, trig_sum:float=0.26, neg_trig_sum:float=0.07, num_steps:int=8, num_samples_per_window:int=4000, run_function=<function validate at 0x7f7b0229c378>)

# %%
wav = read_audio('Achievements_of_the_Democratic_Party_(Homer_S._Cummings).ogg')
# get speech timestamps from full audio file
speech_timestamps = get_speech_ts(wav, model)

# %%
wav[:10]
wav[23219:23219+10]
# Out:
# tensor([-0.0020,  0.0011,  0.0072,  0.0068, -0.0005, -0.0028,  0.0061,  0.0164,
#          0.0170,  0.0113])

# %%
import numpy as np
chunk = torch.Tensor(np.concatenate((wav[:23219].numpy(), wav[23219:46438+23219].numpy())))
get_speech_ts(chunk, model)
# Out:
# [{'start': 22000, 'end': 53500}, {'start': 56000, 'end': 69657}]

# %%
speech_timestamps[0:2]
# Out:
# [{'start': 22000, 'end': 53500}, {'start': 56000, 'end': 72000}]

# %%
from IPython.display import Audio

save_audio('only_speech.wav',
           collect_chunks(st, wav), 16000) 

Audio('only_speech.wav')
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio('Achievements_of_the_Democratic_Party_(Homer_S._Cummings).ogg')
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>
